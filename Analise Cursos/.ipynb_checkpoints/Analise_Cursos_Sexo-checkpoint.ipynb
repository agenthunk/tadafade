# %%
import pandas as pd 
import numpy as np 
import seaborn as sea 
import matplotlib.pyplot as plt 
import random 
# %matplotlib inline

# %% [markdown]
# ### Leitura do Arquivo

# %%
#leitura do arquivo csv
dadosCurso = pd.read_csv('dataset/dados.csv', engine='python', encoding = 'utf8')
print('A base de dados possui %s linhas e %s colunas' % (dadosCurso.shape[0], dadosCurso.shape[1]))
#dadosCurso.head()
# Out:
# A base de dados possui 512 linhas e 7 colunas

# %% [markdown]
# #### Substituindo valores vazios por INDETERMINADO
# #### Definindo valores de Sexo (Masculino/Feminino)

# %%
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(np.nan, 'INDETERMINADO', regex=True)
dadosCurso['Uf'] = dadosCurso['Uf'].replace(np.nan, 'INDETERMINADO', regex=True)
dadosCurso['Bairro'] = dadosCurso['Bairro'].replace(np.nan, 'INDETERMINADO', regex=True)
dadosCurso['Curso'] = dadosCurso['Curso'].replace(np.nan, 'INDETERMINADO', regex=True)
dadosCurso['Sexo'] = dadosCurso['Sexo'].replace(np.nan, 'INDETERMINADO', regex=True)
dadosCurso['Data_Nasc'] = dadosCurso['Data_Nasc'].replace(np.nan, 'INDETERMINADO', regex=True)

dadosCurso['Sexo'] = dadosCurso['Sexo'].replace(['M','F'],['Masculino','Feminino'])

dadosCurso.head()
# Out:
#    Id                Cidade  Uf                        Bairro  \
# 0   1               GOIANIA  GO          RESIDENCIAL ELDORADO
# 1   2               GOIANIA  GO                 ST. PROGRESSO
# 2   3               GOIANIA  GO  RESIDENCIAL RECANTO DAS EMAS
# 3   4               GOIANIA  GO              JARDIM ANA LUCIA
# 4   5  APARECIDA DE GOIANIA  GO                      GARAVELO
#
#                 Curso      Sexo   Data_Nasc
# 0  CIENCIAS CONTABEIS  Feminino  14/06/1978
# 1  CIENCIAS CONTABEIS  Feminino  17/01/1993
# 2  CIENCIAS CONTABEIS  Feminino  14/05/1992
# 3  CIENCIAS CONTABEIS  Feminino  28/09/1993
# 4  CIENCIAS CONTABEIS  Feminino  24/09/1994

# %% [markdown]
# #### Ordenando ASC e conferindo substituição de valores vazios

# %%
dadosCurso.sort_values(by='Id', ascending=True)
# Out:
#       Id                Cidade  Uf                           Bairro  \
# 0      1               GOIANIA  GO             RESIDENCIAL ELDORADO
# 1      2               GOIANIA  GO                    ST. PROGRESSO
# 2      3               GOIANIA  GO     RESIDENCIAL RECANTO DAS EMAS
# 3      4               GOIANIA  GO                 JARDIM ANA LUCIA
# 4      5  APARECIDA DE GOIANIA  GO                         GARAVELO
# 5      6               GOIANIA  GO                      JD PLANALTO
# 6      7               GOIANIA  GO          RESIDENCIAL CENTERVILLE
# 7      8               GOIANIA  GO                    JARDIM EUROPA
# 8      9               GOIANIA  GO              RES. CAMPOS DOURADO
# 9     10               GOIANIA  GO        INDEPEND�NCIA DAS MANS�ES
# 10    11               GOIANIA  GO                    INDETERMINADO
# 11    12               GOIANIA  GO                 JARDIM ATLANTICO
# 12    13               GOIANIA  GO                  RES. TRIUNFO 01
# ...

# %% [markdown]
# ### Listando todas as cidades do cadastro

# %%
listaCidades = dadosCurso['Cidade'].unique().tolist()

for index, item in enumerate(listaCidades):
    print(index, item)
# Out:
# 0 GOIANIA
# 1 APARECIDA DE GOIANIA
# 2 GOI�NIA
# 3 APARECIDA DE GOI�NIA
# 4 AP. DE GOIANIA
# 5 ARAGOIANIA
# 6 APARECIDA DE GOIANIA - GO
# 7 A CONFERIR
# 8 TRINDADE
# 9 TROMBAS
# 10 GOIAS
# 11 GOINIA
# 12 GOIANIRIA
# 13 GOIANA
# 14 GOIANIRA
# 15 CUIABA
# 16 INDETERMINADO
# 17 AP. DE GOI�NIA
# 18 AP.
# 19 SENADOR CANEDO
# 20 ELDORADO
# 21 TRIDADE
# 22 GOI�NIA
# 23 AP DE GOI�NIA
# 24 AP. DE GOINIA
# 25 74494480
# 26 GOIANIA
# 27 APARECIDA DE GOIANIA
# 28 Goi�nia
# 29 GOI�NA

# %% [markdown]
# ### Fazendo o primeiro filtro para organizar e padronizar as cidades

# %%
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['GOIANIRIA'],['Goianira'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['GOIANIRA'],['Goianira'])

dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['TRINDADE'],['Trindade'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['TRIDADE'],['Trindade'])

dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['APARECIDA DE GOIANIA'],['Aparecida de Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['APARECIDA DE GOI�NIA'],['Aparecida de Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['AP. DE GOIANIA'],['Aparecida de Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['APARECIDA DE GOIANIA - GO'],['Aparecida de Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['AP. DE GOI�NIA'],['Aparecida de Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['AP.'],['Aparecida de Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['AP DE GOI�NIA'],['Aparecida de Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['AP. DE GOINIA'],['Aparecida de Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['APARECIDA DE GOIANIA '],['Aparecida de Goiânia'])

dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['GOIANIA'],['Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['GOI�NIA'],['Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['GOINIA'],['Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['GOIANA'],['Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['GOI�NIA '],['Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['GOIANIA '],['Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['Goi�nia '],['Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['GOI�NA'],['Goiânia'])
dadosCurso['Cidade'] = dadosCurso['Cidade'].replace(['74494480'],['Goiânia'])

listaCidadesNova = dadosCurso['Cidade'].unique().tolist()

for index, item in enumerate(listaCidadesNova):
    print(index, item)
# Out:
# 0 Goiânia
# 1 Aparecida de Goiânia
# 2 ARAGOIANIA
# 3 A CONFERIR
# 4 Trindade
# 5 TROMBAS
# 6 GOIAS
# 7 Goianira
# 8 CUIABA
# 9 INDETERMINADO
# 10 SENADOR CANEDO
# 11 ELDORADO

# %% [markdown]
# ### Lista de Cursos

# %%
dadosCurso['Curso'] = dadosCurso['Curso'].replace(['GEST�O DE RECURSOS HUMANOS'],['GESTÃO DE RECURSOS HUMANOS'])
dadosCurso['Curso'] = dadosCurso['Curso'].replace(['SISTEMAS DE INFORMACAO'],['SISTEMAS DE INFORMACÃO'])
dadosCurso['Curso'] = dadosCurso['Curso'].replace(['ADMINISTRACAO'],['ADMINISTRAÇÃO'])
dadosCurso['Curso'] = dadosCurso['Curso'].replace(['CIENCIAS CONTABEIS'],['CIÊNCIAS CONTÁBEIS'])

listaCurso = dadosCurso['Curso'].unique().tolist()

for index, item in enumerate(listaCurso):
    print(index, item)
# Out:
# 0 CIÊNCIAS CONTÁBEIS
# 1 ADMINISTRAÇÃO
# 2 GESTÃO DE RECURSOS HUMANOS
# 3 PEDAGOGIA
# 4 SISTEMAS DE INFORMACÃO

# %% [markdown]
# ### Gráfico de Alunos (Masculino/Feminino) do curso de Ciências Contábeis

# %%
mascCC = (dadosCurso['Sexo'] == 'Masculino') & (dadosCurso['Curso'] == 'CIÊNCIAS CONTÁBEIS')
mascCC = dadosCurso[mascCC]

femCC = (dadosCurso['Sexo'] == 'Feminino') & (dadosCurso['Curso'] == 'CIÊNCIAS CONTÁBEIS')
femCC = dadosCurso[femCC]

print('O curso de Ciências Contábeis tem %s Homens e %s Mulheres' % (mascCC.shape[0], femCC.shape[0]))

labels = ['Masculino', 'Feminino']
quantidade = [mascCC.shape[0], femCC.shape[0]]
cores = ['lightyellow', 'lightgreen']
explode = (0, 0)
total = sum(quantidade)
plt.pie(quantidade, explode=explode, labels=labels, colors=cores, 
       autopct='%1.1f%%', shadow=True, startangle=90)

# Determina que as proporções sejam iguais ('equal') de modo a desenhar o círculo
plt.axis('equal') 
plt.show()
# Out:
# O curso de Ciências Contábeis tem 49 Homens e 100 Mulheres

# %% [markdown]
# ### Gráfico de Alunos (Masculino/Feminino) do curso de Administração

# %%
mascAdm = (dadosCurso['Sexo'] == 'Masculino') & (dadosCurso['Curso'] == 'ADMINISTRAÇÃO')
mascAdm = dadosCurso[mascAdm]

femAdm = (dadosCurso['Sexo'] == 'Feminino') & (dadosCurso['Curso'] == 'ADMINISTRAÇÃO')
femAdm = dadosCurso[femAdm]

print('O curso de Administração tem %s Homens e %s Mulheres' % (mascAdm.shape[0], femAdm.shape[0]))

labels = ['Masculino', 'Feminino']
quantidade = [mascAdm.shape[0], femAdm.shape[0]]
cores = ['lightyellow', 'lightgreen']
explode = (0, 0)
total = sum(quantidade)
plt.pie(quantidade, explode=explode, labels=labels, colors=cores,
       autopct='%1.1f%%', shadow=True, startangle=90)

# Determina que as proporções sejam iguais ('equal') de modo a desenhar o círculo
plt.axis('equal') 
plt.show()
# Out:
# O curso de Administração tem 37 Homens e 78 Mulheres

# %% [markdown]
# ### Gráfico de Alunos (Masculino/Feminino) do curso de  Gestão de Recursos Humanos

# %%
mascGrh = (dadosCurso['Sexo'] == 'Masculino') & (dadosCurso['Curso'] == 'GESTÃO DE RECURSOS HUMANOS')
mascGrh = dadosCurso[mascGrh]

femGrh = (dadosCurso['Sexo'] == 'Feminino') & (dadosCurso['Curso'] == 'GESTÃO DE RECURSOS HUMANOS')
femGrh = dadosCurso[femGrh]

print('O curso de Recursos Humanos tem %s Homens e %s Mulheres' % (mascGrh.shape[0], femGrh.shape[0]))

labels = ['Masculino', 'Feminino']
quantidade = [mascGrh.shape[0], femGrh.shape[0]]
cores = ['lightyellow', 'lightgreen']
explode = (0, 0)
total = sum(quantidade)
plt.pie(quantidade, explode=explode, labels=labels, colors=cores, 
       autopct='%1.1f%%', shadow=True, startangle=90)

# Determina que as proporções sejam iguais ('equal') de modo a desenhar o círculo
plt.axis('equal') 
plt.show()
# Out:
# O curso de Recursos Humanos tem 4 Homens e 29 Mulheres

# %% [markdown]
# ### Gráfico de Alunos (Masculino/Feminino) do curso de Pedagogia

# %%
mascPed = (dadosCurso['Sexo'] == 'Masculino') & (dadosCurso['Curso'] == 'PEDAGOGIA')
mascPed = dadosCurso[mascPed]

femPed = (dadosCurso['Sexo'] == 'Feminino') & (dadosCurso['Curso'] == 'PEDAGOGIA')
femPed = dadosCurso[femPed]

print('O curso de Pedagogia tem %s Homens e %s Mulheres' % (mascPed.shape[0], femPed.shape[0]))

labels = ['Masculino', 'Feminino']
quantidade = [mascPed.shape[0], femPed.shape[0]]
cores = ['lightyellow', 'lightgreen']
explode = (0, 0)
total = sum(quantidade)
plt.pie(quantidade, explode=explode, labels=labels, colors=cores, 
       autopct='%1.1f%%', shadow=True, startangle=90)

# Determina que as proporções sejam iguais ('equal') de modo a desenhar o círculo
plt.axis('equal') 
plt.show()
# Out:
# O curso de Pedagogia tem 7 Homens e 103 Mulheres

# %% [markdown]
# ### Gráfico de Alunos (Masculino/Feminino) do curso de Sistemas de Informação

# %%
#def plota_pizza_1():
mascSis = (dadosCurso['Sexo'] == 'Masculino') & (dadosCurso['Curso'] == 'SISTEMAS DE INFORMACÃO')
mascSis = dadosCurso[mascSis]

femSis = (dadosCurso['Sexo'] == 'Feminino') & (dadosCurso['Curso'] == 'SISTEMAS DE INFORMACÃO')
femSis = dadosCurso[femSis]

print('O curso de Sistemas de Informação tem %s Homens e %s Mulheres' % (mascSis.shape[0], femSis.shape[0]))

labels = ['Masculino', 'Feminino']
quantidade = [mascSis.shape[0], femSis.shape[0]]
cores = ['lightyellow', 'lightgreen']
explode = (0, 0)
total = sum(quantidade)
plt.pie(quantidade, explode=explode, labels=labels, colors=cores, 
       autopct='%1.1f%%', shadow=True, startangle=90)

# Determina que as proporções sejam iguais ('equal') de modo a desenhar o círculo
plt.axis('equal') 
plt.show()
# Out:
# O curso de Sistemas de Informação tem 64 Homens e 41 Mulheres

# %%
#FAZER ABAIXO 
#Preenchendo o campo Cidade INDETERMINADO pela cidade correta através do bairro
#Ex: Se em um registro a cidade está como indeterminada, pega-se* o bairro desse 
#registro e faz uma busca por esse bairro que contenha cidade e substitui a cidade Indeterminada por essa Cidade.
#* Se houver bairro, se não houver, só Deus sabe como faremos...
